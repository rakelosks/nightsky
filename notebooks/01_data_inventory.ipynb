# %% [markdown]
# # 01 — Data Inventory
#
# This notebook documents the four upstream data sources used in the project,
# including their URLs, spatial/temporal coverage, key variables, and access methods.

# %%
import pandas as pd

# %%
data_inventory = pd.DataFrame([
    {
        "dataset": "VIIRS Annual Nighttime Lights (VNL V2)",
        "purpose": "Target variable (light pollution / nighttime brightness)",
        "url": "https://eogdata.mines.edu/products/vnl/",
        "variables": "avg_rad (average radiance), cloud-free observations",
        "years": "2012–2024 (annual composites available)",
        "geography": "global raster (~500m resolution)",
        "format": "GeoTIFF",
        "access": "download (Earth Observation Group)",
        "status": "not tested"
    },
    {
        "dataset": "OpenStreetMap (via Overpass API / OSMnx)",
        "purpose": "Urban characteristics (roads, green areas, land use)",
        "url": "https://overpass-api.de/api/interpreter",
        "variables": "road network, landuse, leisure (parks), building footprints",
        "years": "current snapshot (not historical)",
        "geography": "city-level (custom query)",
        "format": "JSON / XML (API)",
        "access": "API (Overpass) or Python (osmnx)",
        "status": "not tested"
    },
    {
        "dataset": "Eurostat (Population & Density)",
        "purpose": "Socioeconomic variables (population, density)",
        "url": "https://ec.europa.eu/eurostat/api/dissemination/statistics/1.0/data/",
        "variables": "population, population density (varies by dataset)",
        "years": "varies (typically 2010–2024 depending on dataset)",
        "geography": "city / metro / NUTS regions",
        "format": "JSON (API)",
        "access": "API",
        "status": "not tested"
    },
    {
        "dataset": "CelesTrak Starlink Satellites (GP data)",
        "purpose": "Satellite extension (orbital data / satellite density)",
        "url": "https://celestrak.org/NORAD/elements/gp.php?GROUP=starlink&FORMAT=json",
        "variables": "orbital elements (inclination, mean motion, RAAN, etc.)",
        "years": "current (updated every few hours)",
        "geography": "global (orbital positions)",
        "format": "JSON",
        "access": "API",
        "status": "not tested"
    }
])

# %%
data_inventory
# Out:
#                                     dataset  \
# 0    VIIRS Annual Nighttime Lights (VNL V2)
# 1  OpenStreetMap (via Overpass API / OSMnx)
# 2           Eurostat (Population & Density)
# 3   CelesTrak Starlink Satellites (GP data)
#
#                                              purpose  \
# 0  Target variable (light pollution / nighttime b...
# 1  Urban characteristics (roads, green areas, lan...
# 2      Socioeconomic variables (population, density)
# 3  Satellite extension (orbital data / satellite ...
#
#                                                  url  \
# 0            https://eogdata.mines.edu/products/vnl/
# 1            https://overpass-api.de/api/interpreter
# 2  https://ec.europa.eu/eurostat/api/disseminatio...
# 3  https://celestrak.org/NORAD/elements/gp.php?GR...
#
#                                            variables  \
# 0  avg_rad (average radiance), cloud-free observa...
# 1  road network, landuse, leisure (parks), buildi...
# ...
